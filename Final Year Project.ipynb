# %%
import warnings
warnings.filterwarnings('ignore')

import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
# %matplotlib inline

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator , load_img ,img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
from tensorflow.keras.utils import plot_model, img_to_array

# %%
dir_train = 'C:/Users/karan bhise/OneDrive/Desktop/casting_data/casting_data/train/'
dir_train_def = dir_train+'def_front/'
dir_train_ok = dir_train+'ok_front/'

dir_test = 'C:/Users/karan bhise/OneDrive/Desktop/casting_data/casting_data/test/'
dir_test_def = dir_test+'def_front/'
dir_test_ok = dir_test+'ok_front/'

# %%
img = plt.imread(dir_train_def+'/cast_def_0_1001.jpeg')
plt.figure(figsize=(5,5))
plt.imshow(img,cmap='gray')

# %%
img1 = plt.imread(dir_train_ok + '/cast_ok_0_1001.jpeg')
plt.figure(figsize=(5,5))
plt.imshow(img1,cmap='gray')

# %%
train_gen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
test_gen = ImageDataGenerator(rescale=1./255)

image_shape, batch_size, rand_seed = (224, 224, 3), 64, 0
arg_train = {'target_size': image_shape[:2],
             'color_mode': 'rgb',
             'classes': {'ok_front': 0,
                         'def_front': 1},
             'class_mode': 'binary',
             'batch_size': batch_size}
             #'seed': rand_seed}
arg_test = {'target_size': image_shape[:2],
            'color_mode': 'rgb',
            'classes': {'ok_front': 0,
                        'def_front': 1},
            'class_mode': 'binary',
            'batch_size': batch_size,
            #'seed': rand_seed,
            'shuffle': False}
            

train_set = train_gen.flow_from_directory(
    directory=dir_train, subset='training', **arg_train)

valid_set = train_gen.flow_from_directory(
    directory=dir_train, subset='validation', **arg_train)

test_set = test_gen.flow_from_directory(
    directory=dir_test, **arg_test)
# Out:
# Found 5307 images belonging to 2 classes.
# Found 1326 images belonging to 2 classes.
# Found 715 images belonging to 2 classes.

# %%
train_set.class_indices
# Out:
# {'ok_front': 0, 'def_front': 1}

# %%
model = Sequential()

model.add(Conv2D(filters=16, kernel_size=(7,7), strides=2, input_shape=image_shape, activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))

model.add(Conv2D(filters=32, kernel_size=(3,3), strides=1, input_shape=image_shape, activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))

model.add(Conv2D(filters=64, kernel_size=(3,3), strides=1, input_shape=image_shape, activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))

model.add(Flatten())

model.add(Dense(units=224, activation='relu'))

model.add(Dropout(rate=0.2))

model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 112, 112, 16)      2368
#
#  max_pooling2d (MaxPooling2D  (None, 56, 56, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 28, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 224)               2810080
#
#  dropout (Dropout)           (None, 224)               0
#
#  dense_1 (Dense)             (None, 1)                 225
#
# =================================================================
# Total params: 2,835,809
# Trainable params: 2,835,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)

# %%
model_save_path = 'casting_product_detection_normal.hdf5'
early_stop = EarlyStopping(monitor='val_loss',patience=5)
checkpoint = ModelCheckpoint(filepath=model_save_path, verbose=1, save_best_only=True, monitor='val_loss')

# %%
results = model.fit_generator(train_set,
                              epochs=20,
                              validation_data=valid_set,
                              callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/20
# 83/83 [==============================] - ETA: 0s - loss: 0.6837 - accuracy: 0.5915
# Epoch 1: val_loss improved from inf to 0.58224, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 45s 531ms/step - loss: 0.6837 - accuracy: 0.5915 - val_loss: 0.5822 - val_accuracy: 0.6750
# Epoch 2/20
# 83/83 [==============================] - ETA: 0s - loss: 0.4867 - accuracy: 0.7650
# Epoch 2: val_loss improved from 0.58224 to 0.34263, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 44s 531ms/step - loss: 0.4867 - accuracy: 0.7650 - val_loss: 0.3426 - val_accuracy: 0.8778
# Epoch 3/20
# 83/83 [==============================] - ETA: 0s - loss: 0.3070 - accuracy: 0.8675
# Epoch 3: val_loss improved from 0.34263 to 0.24572, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 42s 503ms/step - loss: 0.3070 - accuracy: 0.8675 - val_loss: 0.2457 - val_accuracy: 0.9050
# Epoch 4/20
# 83/83 [==============================] - ETA: 0s - loss: 0.2438 - accuracy: 0.9064
# Epoch 4: val_loss improved from 0.24572 to 0.21325, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 42s 505ms/step - loss: 0.2438 - accuracy: 0.9064 - val_loss: 0.2133 - val_accuracy: 0.9057
# Epoch 5/20
# 83/83 [==============================] - ETA: 0s - loss: 0.2029 - accuracy: 0.9171
# Epoch 5: val_loss improved from 0.21325 to 0.16370, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 43s 515ms/step - loss: 0.2029 - accuracy: 0.9171 - val_loss: 0.1637 - val_accuracy: 0.9336
# Epoch 6/20
# 83/83 [==============================] - ETA: 0s - loss: 0.1642 - accuracy: 0.9369
# Epoch 6: val_loss improved from 0.16370 to 0.13726, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 42s 506ms/step - loss: 0.1642 - accuracy: 0.9369 - val_loss: 0.1373 - val_accuracy: 0.9517
# Epoch 7/20
# 83/83 [==============================] - ETA: 0s - loss: 0.1177 - accuracy: 0.9555
# Epoch 7: val_loss did not improve from 0.13726
# 83/83 [==============================] - 43s 515ms/step - loss: 0.1177 - accuracy: 0.9555 - val_loss: 0.1415 - val_accuracy: 0.9457
# Epoch 8/20
# 83/83 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9585
# Epoch 8: val_loss improved from 0.13726 to 0.08782, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 42s 510ms/step - loss: 0.1042 - accuracy: 0.9585 - val_loss: 0.0878 - val_accuracy: 0.9676
# Epoch 9/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9751
# Epoch 9: val_loss improved from 0.08782 to 0.06608, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 42s 510ms/step - loss: 0.0747 - accuracy: 0.9751 - val_loss: 0.0661 - val_accuracy: 0.9781
# Epoch 10/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9791
# Epoch 10: val_loss did not improve from 0.06608
# 83/83 [==============================] - 43s 513ms/step - loss: 0.0711 - accuracy: 0.9791 - val_loss: 0.0737 - val_accuracy: 0.9736
# Epoch 11/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9857
# Epoch 11: val_loss did not improve from 0.06608
# 83/83 [==============================] - 42s 511ms/step - loss: 0.0518 - accuracy: 0.9857 - val_loss: 0.0883 - val_accuracy: 0.9653
# Epoch 12/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9896
# Epoch 12: val_loss improved from 0.06608 to 0.04062, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 42s 512ms/step - loss: 0.0392 - accuracy: 0.9896 - val_loss: 0.0406 - val_accuracy: 0.9894
# Epoch 13/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9908
# Epoch 13: val_loss improved from 0.04062 to 0.03883, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 43s 518ms/step - loss: 0.0345 - accuracy: 0.9908 - val_loss: 0.0388 - val_accuracy: 0.9879
# Epoch 14/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9919
# Epoch 14: val_loss improved from 0.03883 to 0.03720, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 42s 511ms/step - loss: 0.0274 - accuracy: 0.9919 - val_loss: 0.0372 - val_accuracy: 0.9910
# Epoch 15/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9821
# Epoch 15: val_loss did not improve from 0.03720
# 83/83 [==============================] - 43s 512ms/step - loss: 0.0543 - accuracy: 0.9821 - val_loss: 0.0407 - val_accuracy: 0.9879
# Epoch 16/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9923
# Epoch 16: val_loss improved from 0.03720 to 0.03516, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 43s 513ms/step - loss: 0.0288 - accuracy: 0.9923 - val_loss: 0.0352 - val_accuracy: 0.9902
# Epoch 17/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9932
# Epoch 17: val_loss improved from 0.03516 to 0.03123, saving model to casting_product_detection_normal.hdf5
# 83/83 [==============================] - 42s 512ms/step - loss: 0.0253 - accuracy: 0.9932 - val_loss: 0.0312 - val_accuracy: 0.9910
# Epoch 18/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9947
# Epoch 18: val_loss did not improve from 0.03123
# 83/83 [==============================] - 43s 518ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0403 - val_accuracy: 0.9894
# Epoch 19/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9951
# Epoch 19: val_loss did not improve from 0.03123
# 83/83 [==============================] - 43s 512ms/step - loss: 0.0179 - accuracy: 0.9951 - val_loss: 0.0395 - val_accuracy: 0.9864
# Epoch 20/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9917
# Epoch 20: val_loss did not improve from 0.03123
# 83/83 [==============================] - 43s 519ms/step - loss: 0.0269 - accuracy: 0.9917 - val_loss: 0.0314 - val_accuracy: 0.9917

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses[['loss','val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
losses[['accuracy','val_accuracy']].plot()
# Out:
# <AxesSubplot:>

# %%
model = load_model('casting_product_detection_normal.hdf5')

# %%
y_pred_prob = model.predict(test_set, verbose=1)
y_pred = (y_pred_prob >= 0.5).reshape(-1,)
y_true = test_set.classes[test_set.index_array]
# Out:
# 12/12 [==============================] - 2s 127ms/step

# %%
print(classification_report(test_set.classes,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       262
#            1       1.00      1.00      1.00       453
#
#     accuracy                           1.00       715
#    macro avg       1.00      1.00      1.00       715
# weighted avg       1.00      1.00      1.00       715

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax = sns.heatmap(confusion_matrix(y_true,y_pred), annot=True,
                 annot_kws={'size':11, 'weight':'bold'},
                 fmt='d', cbar=False, cmap='Greens')
ax.set_xlabel("Predicted", fontsize=14, labelpad=20)
ax.set_ylabel("Actual", fontsize=14, labelpad=20)
ax.set_xticklabels(['OK', 'Defective'])
ax.set_yticklabels(['OK', 'Defective'], va='center')

ax.set_title("Confusion Matrix", fontsize=14, pad=20)
plt.show()

# %%
img = cv2.imread(dir_test+'ok_front/cast_ok_0_1020.jpeg')
img = cv2.resize(img, (224, 224))
img = img/255
pred_img =img.copy()

# %%
plt.figure(figsize=(5,5))
plt.imshow(img, cmap='gray')

# %%
prediction = model.predict(img.reshape(1, *image_shape))
prediction
# Out:
# 1/1 [==============================] - 0s 66ms/step
# array([[0.0021329]], dtype=float32)

# %%
if (prediction<0.5):
    print("ok_front")
    cv2.putText(pred_img, "ok_front", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
else:
    print("def_front")
    cv2.putText(pred_img, "def_front", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
    
plt.imshow(pred_img,cmap='gray')
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ok_front

# %%
img1 = cv2.imread(dir_test+'def_front/cast_def_0_1134.jpeg')
img1 = cv2.resize(img1, (224, 224))
img1 = img1/255
pred_img1 =img1.copy()

# %%
plt.figure(figsize=(5,5))
plt.imshow(img1, cmap='gray')

# %%
prediction = model.predict(img1.reshape(1, *image_shape))
prediction
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([[1.]], dtype=float32)

# %%
if (prediction<0.5):
    print("ok_front")
    cv2.putText(pred_img1, "ok_front", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
else:
    print("def_front")
    cv2.putText(pred_img1, "def_front", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
    
plt.imshow(pred_img1,cmap='gray')
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# def_front

# %%
test_cases = ['ok_front/cast_ok_0_10.jpeg', 'ok_front/cast_ok_0_1026.jpeg', 'ok_front/cast_ok_0_1031.jpeg', 'ok_front/cast_ok_0_1121.jpeg', \
              'ok_front/cast_ok_0_1144.jpeg','def_front/cast_def_0_1059.jpeg', 'def_front/cast_def_0_108.jpeg', 'def_front/cast_def_0_1153.jpeg',\
              'def_front/cast_def_0_1238.jpeg', 'def_front/cast_def_0_1269.jpeg']

plt.figure(figsize=(20,8))
for i in range(len(test_cases)):
    img_pred = cv2.imread(dir_test + test_cases[i])
    img_pred = cv2.resize(img_pred, (224, 224))
    img_pred = img_pred / 255
    prediction = model.predict(img_pred.reshape(1, 224, 224, 3))
    
    img = cv2.imread(dir_test + test_cases[i])
    label = test_cases[i].split("_")[0]
    
    plt.subplot(2, 5, i+1)
    plt.title(f"{test_cases[i].split('/')[1]}\n Actual Label : {label}", weight='bold', size=12)

    if (prediction < 0.5):
        predicted_label = "ok"
        prob = (1-prediction.sum()) * 100

    else:
        predicted_label = "def"
        prob = prediction.sum() * 100
        
    cv2.putText(img=img, text=f"Predicted Label : {predicted_label}", org=(10, 30), fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=0.8, color=(255, 0, 255), thickness=2)
    cv2.putText(img=img, text=f"Probability : {'{:.3f}'.format(prob)}%", org=(10, 280), fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=0.7, color=(0, 255, 0), thickness=2)
    plt.imshow(img,cmap='gray')
    plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
